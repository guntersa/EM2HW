# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
o=10
x=np.arange(-.5,.5,.01)
f=np.exp(-((x**2)*o**2)/2)
plt.plot(x,f)

# %% [markdown]
# As time goes on, the wave travels in space, but it dies out as it loses energy.
